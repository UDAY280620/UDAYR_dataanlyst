# %%
import pandas as pd

# %%
df = pd.read_csv('RA.csv')

# %%
print(df.head())
# Out:
#   Million Plus Cities   Cause category        Cause Subcategory  \
# 0                Agra  Traffic Control  Flashing Signal/Blinker
# 1                Agra  Traffic Control  Flashing Signal/Blinker
# 2                Agra  Traffic Control  Flashing Signal/Blinker
# 3                Agra  Traffic Control  Flashing Signal/Blinker
# 4                Agra  Traffic Control  Flashing Signal/Blinker
#
#          Outcome of Incident  Count
# 0         Greviously Injured    0.0
# 1               Minor Injury    0.0
# 2             Persons Killed    0.0
# 3              Total Injured    0.0
# 4  Total number of Accidents    0.0

# %%
print(df.isnull().sum())
# Out:
# Million Plus Cities    0
# Cause category         0
# Cause Subcategory      0
# Outcome of Incident    0
# Count                  3
# dtype: int64

# %%
df_cleaned = df.dropna()

# %%
print(df_cleaned.isnull().sum())
# Out:
# Million Plus Cities    0
# Cause category         0
# Cause Subcategory      0
# Outcome of Incident    0
# Count                  0
# dtype: int64

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
plt.figure(figsize=(12,6))
sns.countplot(y='Million Plus Cities', data=df_cleaned, order=df_cleaned['Million Plus Cities'].value_counts().index)
# Out:
# <Axes: xlabel='count', ylabel='Million Plus Cities'>

# %%
plt.title('Distribution of Road Accidents in Million-Plus Cities')
# Out:
# Text(0.5, 1.0, 'Distribution of Road Accidents in Million-Plus Cities')

# %%
plt.xlabel('Number of Accidents')
# Out:
# Text(0.5, 0, 'Number of Accidents')

# %%
plt.ylabel('Cities')
# Out:
# Text(0, 0.5, 'Cities')

# %%
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(y='Cause category', data=df_cleaned, order=df_cleaned['Cause category'].value_counts().index)
# Out:
# <Axes: xlabel='count', ylabel='Cause category'>

# %%
plt.title('Distribution of Accident Causes')
# Out:
# Text(0.5, 1.0, 'Distribution of Accident Causes')

# %%
plt.xlabel('Number of Accidents')
# Out:
# Text(0.5, 0, 'Number of Accidents')

# %%
plt.ylabel('Cause Category')
# Out:
# Text(0, 0.5, 'Cause Category')

# %%
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(y='Cause Subcategory', data=df_cleaned,order=df_cleaned['Cause Subcategory'].value_counts().index)
# Out:
# <Axes: xlabel='count', ylabel='Cause Subcategory'>

# %%
plt.title('Detailed Analysis of Accident Causes by Subcategory')
# Out:
# Text(0.5, 1.0, 'Detailed Analysis of Accident Causes by Subcategory')

# %%
plt.xlabel('Number of Accidents')
# Out:
# Text(0.5, 0, 'Number of Accidents')

# %%
plt.ylabel('Cause Subcategory')
# Out:
# Text(0, 0.5, 'Cause Subcategory')

# %%
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Outcome of Incident', data=df_cleaned, order=df_cleaned['Outcome of Incident'].value_counts().index)
# Out:
# <Axes: xlabel='Outcome of Incident', ylabel='count'>

# %%
plt.title('Outcome of Road Accidents')
# Out:
# Text(0.5, 1.0, 'Outcome of Road Accidents')

# %%
plt.xlabel('Outcome')
# Out:
# Text(0.5, 0, 'Outcome')

# %%
plt.ylabel('Number of Incidents')
# Out:
# Text(0, 0.5, 'Number of Incidents')

# %%
plt.show()

# %%
outcome_vs_cause = df_cleaned.groupby(['Cause category',
'Outcome of Incident'])['Count'].sum().unstack()

# %%
outcome_vs_cause.plot(kind='bar', stacked=True,figsize=(12,8))
# Out:
# <Axes: xlabel='Cause category'>

# %%
plt.title('Accident Causes vs Outcomes')
# Out:
# Text(0.5, 1.0, 'Accident Causes vs Outcomes')

# %%
plt.xlabel('Cause Category')
# Out:
# Text(0.5, 0, 'Cause Category')

# %%
plt.ylabel('Number of Incidents')
# Out:
# Text(0, 0.5, 'Number of Incidents')

# %% [markdown]
# plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# ##### The cities with the highest number of accidents

# %%
1. Chennai – 26,334 accidents
2. Delhi – 25,068 accidents
3. Bengaluru – 19,398 accidents
4. Jabalpur – 19,356 accidents
5. Indore – 18,216 accidents

# %% [markdown]
# ##### The most common causes of accidents

# %%
The data groups causes under broad categories, each contributing 58,736 accidents, suggesting either uniform categorization or possible data aggregation. The categories include:

1. Impacting Vehicle/Object
2. Junction
3. Road Features
4. Traffic Control
5. Traffic Violation
6. Weather

# %% [markdown]
# ##### The relationship between causes and outcomes of road accidents

# %%
1. Grievously Injured: 20,532 people
2. Minor Injury: 29,983 people
3. Persons Killed: 13,542 people
4. Total number of Accidents: 58,736
